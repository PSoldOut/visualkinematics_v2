# %%
from pythreejs import *
from ipywidgets import *
import visualkinematics_v2.util as util
import visualkinematics_v2.show as show

# %%
cube = util.create_colored_quad([0,0,0],1,1,1, transparent=False)
env = show.Environment(grid=util.create_grid_XY(10,0.4), frame=util.create_axes(4), widgets_on_bottom=True)
env.camera.position=[3,3,3]
env.add(cube)
env.add_gizmo_controls(cube)

display(env)
