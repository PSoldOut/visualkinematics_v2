# %%
import pythreejs as three
from pythreejs import *
from ipywidgets import *
from IPython.display import display
import numpy as np
from stl import mesh
import util
import time

# %%
kuka = three.Group()
mesh1 = util.load_mesh_from_npz("../assets/npz/kuka_parts1.npz")
mesh2 = util.load_mesh_from_npz("../assets/npz/kuka_parts2.npz")
mesh3 = util.load_mesh_from_npz("../assets/npz/kuka_parts3.npz")
mesh4 = util.load_mesh_from_npz("../assets/npz/kuka_parts4.npz")
mesh5 = util.load_mesh_from_npz("../assets/npz/kuka_parts5.npz")
kuka.add([mesh1, mesh2, mesh3, mesh4, mesh5])
# Out:
# c:\Users\Philipp\Desktop\gitProjects\visualkinematics_v2\.venv\lib\site-packages\pythreejs\traits.py:257: UserWarning: 64-bit data types not supported for WebGL data, casting to 32-bit.
#   warnings.warn('64-bit data types not supported for WebGL '

# %%
start_np = time.perf_counter()
mesh_obj1 = util.load_mesh_from_stl("../assets/stl/KUKA_KR_140_R3200_2_PA_ASM/link2.stl")
end_np = time.perf_counter()
print(end_np - start_np)

start_np = time.perf_counter()
mesh_obj2 = util.load_mesh_from_npz("../assets/npz/KUKA_KR_140_R3200_2_PA_ASM/link2.npz")
end_np = time.perf_counter()
print(end_np - start_np)
# Out:
# 0.2402148999972269
# 0.12968860000546556

# %%
mesh_obj2.scale = [0.002,0.002,0.002]

def to_hex(rgb):
    return '#{:02x}{:02x}{:02x}'.format(
        int(rgb[0]*255),
        int(rgb[1]*255),
        int(rgb[2]*255)
    )


env = util.Environment()
env.light.position = [5,5,25]



env.add([mesh_obj1, mesh_obj2])
env.add_gizmo_controls(mesh_obj2)
display(env)
# Out:
# Renderer(camera=PerspectiveCamera(aspect=1.4, position=(8.0, 8.0, 8.0), projectionMatrix=(1.0, 0.0, 0.0, 0.0, …
# ...
# Dropdown(description='Rotation Order:', index=5, options=('XYZ', 'XZY', 'YXZ', 'YZX', 'ZXY', 'ZYX', 'ZYZ', 'XY…
