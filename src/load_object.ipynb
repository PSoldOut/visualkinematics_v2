# %%
from pythreejs import *
from ipywidgets import *
from IPython.display import display
import numpy as np
import util




env = util.Environment()
env.light.position = [5,5,25]

robot = util.Manipulator("irb6640_185_280")
env.add_gizmo_controls(robot)
#env.add_gizmo_controls(robot.children[0])
#env.add_gizmo_controls(robot.children[0].children[0])
#env.add_gizmo_controls(robot.children[0].children[0].children[0])

env.add([robot])
display(env)
# Out:
# {
#     "links": [
#         {
#             "name": "base_link",
#             "visual": [
#                 {
#                     "origin": null,
#                     "geometry": {
#                         "type": "mesh",
#                         "filename": "c:/Users/Philipp/Desktop/gitProjects/visualkinematics_v2/assets/ros-package-sets/abb-noetic-devel/abb_irb6640_support/meshes/irb6640_185_280/visual/base_link.dae",
#                         "scale": "1 1 1"
#                     },
#                     "material": {
#                         "name": "yellow"
#                     }
#                 }
#             ],
#             "collision": [
#                 {
#                     "origin": null,
#                     "geometry": {
#                         "type": "mesh",
#                         "filename": "c:/Users/Philipp/Desktop/gitProjects/visualkinematics_v2/assets/ros-package-sets/abb-noetic-devel/abb_irb6640_support/meshes/irb6640_185_280/collision/base_link.stl",
#                         "scale": "1 1 1"
#                     },
#                     "material": null
#                 }
#             ],
#             "inertial": null
#         },
#         {
#             "name": "link_1",
#             "visual": [
#                 {
#                     "origin": null,
#                     "geometry": {
#                         "type": "mesh",
#                         "filename": "c:/Users/Philipp/Desktop/gitProjects/visualkinematics_v2/assets/ros-package-sets/abb-noetic-devel/abb_irb6640_support/meshes/irb6640_185_280/visual/link_1.dae",
#                         "scale": "1 1 1"
#                     },
#                     "material": {
#                         "name": "yellow"
#                     }
#                 }
#             ],
#             "collision": [
#                 {
#                     "origin": null,
#                     "geometry": {
#                         "type": "mesh",
#                         "filename": "c:/Users/Philipp/Desktop/gitProjects/visualkinematics_v2/assets/ros-package-sets/abb-noetic-devel/abb_irb6640_support/meshes/irb6640_185_280/collision/link_1.stl",
#                         "scale": "1 1 1"
#                     },
#                     "material": null
#                 }
#             ],
#             "inertial": null
#         },
#         {
#             "name": "link_2",
#             "visual": [
#                 {
#                     "origin": null,
#                     "geometry": {
#                         "type": "mesh",
#                         "filename": "c:/Users/Philipp/Desktop/gitProjects/visualkinematics_v2/assets/ros-package-sets/abb-noetic-devel/abb_irb6640_support/meshes/irb6640_185_280/visual/link_2.dae",
#                         "scale": "1 1 1"
#                     },
#                     "material": {
#                         "name": "yellow"
#                     }
#                 }
#             ],
#             "collision": [
#                 {
#                     "origin": null,
#                     "geometry": {
#                         "type": "mesh",
#                         "filename": "c:/Users/Philipp/Desktop/gitProjects/visualkinematics_v2/assets/ros-package-sets/abb-noetic-devel/abb_irb6640_support/meshes/irb6640_185_280/collision/link_2.stl",
#                         "scale": "1 1 1"
#                     },
#                     "material": null
#                 }
#             ],
#             "inertial": null
#         },
#         {
#             "name": "link_3",
#             "visual": [
#                 {
#                     "origin": null,
#                     "geometry": {
#                         "type": "mesh",
#                         "filename": "c:/Users/Philipp/Desktop/gitProjects/visualkinematics_v2/assets/ros-package-sets/abb-noetic-devel/abb_irb6640_support/meshes/irb6640_185_280/visual/link_3.dae",
#                         "scale": "1 1 1"
#                     },
#                     "material": {
#                         "name": "yellow"
#                     }
#                 }
#             ],
#             "collision": [
#                 {
#                     "origin": null,
#                     "geometry": {
#                         "type": "mesh",
#                         "filename": "c:/Users/Philipp/Desktop/gitProjects/visualkinematics_v2/assets/ros-package-sets/abb-noetic-devel/abb_irb6640_support/meshes/irb6640_185_280/collision/link_3.stl",
#                         "scale": "1 1 1"
#                     },
#                     "material": null
#                 }
#             ],
#             "inertial": null
#         },
#         {
#             "name": "link_4",
#             "visual": [
#                 {
#                     "origin": null,
#                     "geometry": {
#                         "type": "mesh",
#                         "filename": "c:/Users/Philipp/Desktop/gitProjects/visualkinematics_v2/assets/ros-package-sets/abb-noetic-devel/abb_irb6640_support/meshes/irb6640_185_280/visual/link_4.dae",
#                         "scale": "1 1 1"
#                     },
#                     "material": {
#                         "name": "yellow"
#                     }
#                 }
#             ],
#             "collision": [
#                 {
#                     "origin": null,
#                     "geometry": {
#                         "type": "mesh",
#                         "filename": "c:/Users/Philipp/Desktop/gitProjects/visualkinematics_v2/assets/ros-package-sets/abb-noetic-devel/abb_irb6640_support/meshes/irb6640_185_280/collision/link_4.stl",
#                         "scale": "1 1 1"
#                     },
#                     "material": null
#                 }
#             ],
#             "inertial": null
#         },
#         {
#             "name": "link_5",
#             "visual": [
#                 {
#                     "origin": null,
#                     "geometry": {
#                         "type": "mesh",
#                         "filename": "c:/Users/Philipp/Desktop/gitProjects/visualkinematics_v2/assets/ros-package-sets/abb-noetic-devel/abb_irb6640_support/meshes/irb6640_185_280/visual/link_5.dae",
#                         "scale": "1 1 1"
#                     },
#                     "material": {
#                         "name": "yellow"
#                     }
#                 }
#             ],
#             "collision": [
#                 {
#                     "origin": null,
#                     "geometry": {
#                         "type": "mesh",
#                         "filename": "c:/Users/Philipp/Desktop/gitProjects/visualkinematics_v2/assets/ros-package-sets/abb-noetic-devel/abb_irb6640_support/meshes/irb6640_185_280/collision/link_5.stl",
#                         "scale": "1 1 1"
#                     },
#                     "material": null
#                 }
#             ],
#             "inertial": null
#         },
#         {
#             "name": "link_6",
#             "visual": [
#                 {
#                     "origin": null,
#                     "geometry": {
#                         "type": "mesh",
#                         "filename": "c:/Users/Philipp/Desktop/gitProjects/visualkinematics_v2/assets/ros-package-sets/abb-noetic-devel/abb_irb6640_support/meshes/irb6640_185_280/visual/link_6.dae",
#                         "scale": "1 1 1"
#                     },
#                     "material": {
#                         "name": "yellow"
#                     }
#                 }
#             ],
#             "collision": [
#                 {
#                     "origin": null,
#                     "geometry": {
#                         "type": "mesh",
#                         "filename": "c:/Users/Philipp/Desktop/gitProjects/visualkinematics_v2/assets/ros-package-sets/abb-noetic-devel/abb_irb6640_support/meshes/irb6640_185_280/collision/link_6.stl",
#                         "scale": "1 1 1"
#                     },
#                     "material": null
#                 }
#             ],
#             "inertial": null
#         },
#         {
#             "name": "tool0",
#             "visual": [],
#             "collision": [],
#             "inertial": null
#         },
#         {
#             "name": "link_cylinder",
#             "visual": [
#                 {
#                     "origin": null,
#                     "geometry": {
#                         "type": "mesh",
#                         "filename": "c:/Users/Philipp/Desktop/gitProjects/visualkinematics_v2/assets/ros-package-sets/abb-noetic-devel/abb_irb6640_support/meshes/irb6640_185_280/visual/cylinder_link.dae",
#                         "scale": "1 1 1"
#                     },
#                     "material": {
#                         "name": "yellow"
#                     }
#                 }
#             ],
#             "collision": [
#                 {
#                     "origin": null,
#                     "geometry": {
#                         "type": "mesh",
#                         "filename": "c:/Users/Philipp/Desktop/gitProjects/visualkinematics_v2/assets/ros-package-sets/abb-noetic-devel/abb_irb6640_support/meshes/irb6640_185_280/collision/cylinder_link.stl",
#                         "scale": "1 1 1"
#                     },
#                     "material": null
#                 }
#             ],
#             "inertial": null
#         },
#         {
#             "name": "link_piston",
#             "visual": [
#                 {
#                     "origin": null,
#                     "geometry": {
#                         "type": "mesh",
#                         "filename": "c:/Users/Philipp/Desktop/gitProjects/visualkinematics_v2/assets/ros-package-sets/abb-noetic-devel/abb_irb6640_support/meshes/irb6640_185_280/visual/piston_link.dae",
#                         "scale": "1 1 1"
#                     },
#                     "material": {
#                         "name": "yellow"
#                     }
#                 }
#             ],
#             "collision": [
#                 {
#                     "origin": null,
#                     "geometry": {
#                         "type": "mesh",
#                         "filename": "c:/Users/Philipp/Desktop/gitProjects/visualkinematics_v2/assets/ros-package-sets/abb-noetic-devel/abb_irb6640_support/meshes/irb6640_185_280/collision/piston_link.stl",
#                         "scale": "1 1 1"
#                     },
#                     "material": null
#                 }
#             ],
#             "inertial": null
#         },
#         {
#             "name": "base",
#             "visual": [],
#             "collision": [],
#             "inertial": null
#         }
#     ],
#     "joints": [
#         {
#             "name": "joint_1",
#             "type": "revolute",
#             "parent": "base_link",
#             "child": "link_1",
#             "origin": {
#                 "rpy": "0 0 0",
#                 "xyz": "0 0 0.780"
#             },
#             "axis": {
#                 "xyz": "0 0 1"
#             }
#         },
#         {
#             "name": "joint_2",
#             "type": "revolute",
#             "parent": "link_1",
#             "child": "link_2",
#             "origin": {
#                 "rpy": "0 0 0",
#                 "xyz": "0.320 0 0"
#             },
#             "axis": {
#                 "xyz": "0 1 0"
#             }
#         },
#         {
#             "name": "joint_3",
#             "type": "revolute",
#             "parent": "link_2",
#             "child": "link_3",
#             "origin": {
#                 "rpy": "0 0 0",
#                 "xyz": "0 0 1.075"
#             },
#             "axis": {
#                 "xyz": "0 1 0"
#             }
#         },
#         {
#             "name": "joint_4",
#             "type": "revolute",
#             "parent": "link_3",
#             "child": "link_4",
#             "origin": {
#                 "rpy": "0 0 0",
#                 "xyz": "0 0 0.2"
#             },
#             "axis": {
#                 "xyz": "1 0 0"
#             }
#         },
#         {
#             "name": "joint_5",
#             "type": "revolute",
#             "parent": "link_4",
#             "child": "link_5",
#             "origin": {
#                 "rpy": "0 0 0",
#                 "xyz": "1.392 0 0 "
#             },
#             "axis": {
#                 "xyz": "0 1 0"
#             }
#         },
#         {
#             "name": "joint_6",
#             "type": "revolute",
#             "parent": "link_5",
#             "child": "link_6",
#             "origin": {
#                 "rpy": "0 0 0",
#                 "xyz": "0.2 0 0 "
#             },
#             "axis": {
#                 "xyz": "1 0 0"
#             }
#         },
#         {
#             "name": "joint_6-tool0",
#             "type": "fixed",
#             "parent": "link_6",
#             "child": "tool0",
#             "origin": {
#                 "rpy": "0 1.57079632679 0",
#                 "xyz": "0 0 0"
#             },
#             "axis": null
#         },
#         {
#             "name": "joint_cylinder",
#             "type": "continuous",
#             "parent": "link_1",
#             "child": "link_cylinder",
#             "origin": {
#                 "rpy": "0 0 0",
#                 "xyz": "-0.3647 0 -0.1455"
#             },
#             "axis": {
#                 "xyz": "0 1 0"
#             }
#         },
#         {
#             "name": "joint_piston",
#             "type": "continuous",
#             "parent": "link_2",
#             "child": "link_piston",
#             "origin": {
#                 "rpy": "0 0 0",
#                 "xyz": "-0.22 0 -0.0672"
#             },
#             "axis": {
#                 "xyz": "0 1 0"
#             }
#         },
#         {
#             "name": "base_link-base",
#             "type": "fixed",
#             "parent": "base_link",
#             "child": "base",
#             "origin": {
#                 "rpy": "0 0 0",
#                 "xyz": "0 0 0"
#             },
#             "axis": null
#         }
#     ]
# }
# base_link
# link_1
# link_2
# link_3
# link_4
# link_5
# link_6
# link_cylinder
# link_piston
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 13
#      10 env = util.Environment()
#      11 env.light.position = [5,5,25]
# ---> 13 robot = util.Manipulator("irb6640_185_280")
#      14 env.add_gizmo_controls(robot)
#      15 #env.add_gizmo_controls(robot.children[0])
#      16 #env.add_gizmo_controls(robot.children[0].children[0])
#      17 #env.add_gizmo_controls(robot.children[0].children[0].children[0])
#
# File c:\Users\Philipp\Desktop\gitProjects\visualkinematics_v2\src\util.py:1466, in Manipulator.__init__(self, name)
#    1462 joint = Joint(joint_element["name"], pos, angles)
#    1464 #print(joint_parent)
#    1465 #print(joint_child)
# -> 1466 joint.add(joint_child)
#    1467 joint_parent.add(joint)
#    1468 self.joints.append(joint)
#
# File c:\Users\Philipp\Desktop\gitProjects\visualkinematics_v2\src\util.py:1367, in Kinematic_Chain_Element.add(self, object)
#    1365 if hasattr(object, "get_renderable"):
#    1366     renderable = object.get_renderable()
# -> 1367 self.renderable.add(renderable)
#    1368 self.children.append(object)
#    1369 if isinstance(object, Kinematic_Chain_Element):
#
# File c:\Users\Philipp\Desktop\gitProjects\visualkinematics_v2\.venv\lib\site-packages\pythreejs\core\Object3D.py:16, in Object3D.add(self, children)
#      14     children = [children]
#      15 children_list = list(self.children)
# ---> 16 children_list.extend(children)
#      18 self.children = tuple(children_list)
#
# TypeError: 'NoneType' object is not iterable

# %%
robot.links[2].remove(robot.links[3])
