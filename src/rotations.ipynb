# %%
from pythreejs import *
from ipywidgets import *
import util

# %%
cube = util.create_colored_quad([0,0,0],1,1,1)
env = util.Environment(grid=util.create_grid_XY(10,0.4), frame=util.create_axes(4))
env.camera.position=[3,3,3]
env.add(cube)
env.add_gizmo_controls(cube)

display(env)
# Out:
# HBox(children=(VBox(children=(Renderer(camera=PerspectiveCamera(aspect=1.4, position=(3.0, 3.0, 3.0), projecti…
# VBox()
