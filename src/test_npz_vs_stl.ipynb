# %%
import trimesh
import numpy as np
from pythreejs import *
import time

start = time.perf_counter()

mesh = trimesh.load("C:/Users/Philipp/Desktop/gitProjects/visualkinematics_v2/assets/ros-package-sets/kuka_experimental-melodic-devel/kuka_kr10_support/meshes/kr10r900_2/visual/base_link.stl", force='mesh')
    
end = time.perf_counter()
elapsed = end - start
print(f"Ausführungszeit1: {elapsed:.6f} Sekunden")









start = time.perf_counter()

data = np.load("C:/Users/Philipp/Desktop/gitProjects/visualkinematics_v2/assets/npz/kr6r900_2/base_link.npz")
    
end = time.perf_counter()
elapsed = end - start
print(f"Ausführungszeit2: {elapsed:.6f} Sekunden")
# Out:
# Ausführungszeit1: 0.003276 Sekunden
# Ausführungszeit2: 0.000267 Sekunden
